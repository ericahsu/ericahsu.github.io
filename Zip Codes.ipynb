# %%
import pandas as pd

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

df = pd.read_csv('coviddata5.csv')

df2 = pd.read_csv('/Users/erica/Downloads/californiazipcodes.csv')

df2.sort_values(by='Zip', inplace = True)

df3 = df2[['Zip', 'Latitude', 'Longitude']]
df3['Zip'].isin(df['Zip Code'])
df3[df3.Zip.isin(df['Zip Code'])]
# Out:
#         Zip   Latitude   Longitude
# 911   91901  32.823102 -116.738640
# 101   91902  32.663803 -117.024560
# 844   91910  32.638654 -117.066860
# 2049  91911  32.608799 -117.060700
# 2064  91913  32.642486 -116.989730
# 1115  91914  32.662563 -116.954130
# 2700  91915  32.638072 -116.951950
# 2557  91932  32.579555 -117.117080
# 1261  91941  32.761801 -117.012730
# 421   91942  32.785000 -117.018600
# 1259  91945  32.733451 -117.033700
# 2494  91950  32.670903 -117.092720
# 2547  91977  32.721145 -116.996120
# 1569  92007  33.026742 -117.278160
# 766   92008  33.158137 -117.326460
# 217   92009  33.097841 -117.267440
# 2274  92014  32.961812 -117.259670
# 1031  92019  32.788736 -116.904870
# 1128  92020  32.799100 -116.973340
# 919   92021  32.820100 -116.912340
# 79    92024  33.053092 -117.268550
# 2555  92025  33.106862 -117.070770
# 548   92026  33.181543 -117.111360
# 1164  92027  33.142706 -117.030490
# 2161  92028  33.380359 -117.206050
# 1447  92029  33.087868 -117.115580
# ...
